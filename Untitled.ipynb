# %%
import pandas as pd
localdb=[]
localdb.append(["nahyunAsisstant - short instructions","2024-05-16 17:23:01","안녕","안녕하세요! 어떻게 지내세요? 요즘 기분이나 생각은 어떠신가요? 공유하고 싶은 이야기가 있으면 언제든 자유롭게 말씀해 주세요. 😊",847])
localdb.append(["nahyunAsisstant - short instructions","2024-05-16 17:23:02","요즘 나의 기분 어떤지 알려줘","a" ,12234])
localdb.append(["nahyunAsisstant - short instructions","2024-05-16 17:23:03","요즘 나의 기분 알려줘","b" ,"?"])
localdb.append(["nahyunAsisstant - short instructions","2024-05-16 17:23:08","요즘 나의 기분 알려줘","c" ,14107])
localdb.append(["nahyunAsisstant","2024-05-16 18:23:06","요즘 나의 기분 알려줘","요즘 기분이 전반적으로 즐겁지만 약간의 고민과 스트레스가 섞여 있는 듯해요. 최근 일상과 다양한 활동 속에서 재미를 느끼고 있지만, 동시에 공부나 과제에 대한 부담도 느끼고 있네요[1]``[2]. 어쨌든 새로운 도전들과 활발한 사회활동으로 인해 활기찬 하루하루를 보내고 있는 것 같아요[3]``[4]." ,11717])
localdb.append(["nahyunAsisstant - short instructions","2024-05-16 18:23:10","최근 기록에 따르면 불안함과 동요가 있는 것 같아요[1]``[2]. 그러나 바쁠 때에는 오히려 집중이 잘 되어 잡생각이 줄어드는 것을 느꼈어요[3]. 전반적으로 인생과 자신의 선택에 대한 많은 고민이 느껴지지만, 성장하고 있는 부분도 인식하고 있어요[4]``[5].. ",11771])
df=pd.DataFrame(localdb, columns=['api_name','date','user','ai','tokens'])
df
# Out:
#                                api_name                 date  \
# 0  nahyunAsisstant - short instructions  2024-05-16 17:23:01
# 1  nahyunAsisstant - short instructions  2024-05-16 17:23:02
# 2  nahyunAsisstant - short instructions  2024-05-16 17:23:03
# 3  nahyunAsisstant - short instructions  2024-05-16 17:23:08
# 4                       nahyunAsisstant  2024-05-16 18:23:06
# 5  nahyunAsisstant - short instructions  2024-05-16 18:23:10
#
#                                                 user  \
# 0                                                 안녕
# 1                                   요즘 나의 기분 어떤지 알려줘
# 2                                       요즘 나의 기분 알려줘
# 3                                       요즘 나의 기분 알려줘
# 4                                       요즘 나의 기분 알려줘
# 5  최근 기록에 따르면 불안함과 동요가 있는 것 같아요[1]``[2]. 그러나 바쁠 때...
#
#                                                   ai tokens
# 0  안녕하세요! 어떻게 지내세요? 요즘 기분이나 생각은 어떠신가요? 공유하고 싶은 이야...    847
# ...
